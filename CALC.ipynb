# %%
from tkinter import *

def oper(event):
    global pos
    global ans
    l = []
    s = ent.get()
    s = s.split()
    try:
        if s[1] == '+':
            l.append(float(s[0]) + float(s[2]))
            lab['text'] = l[-1]

        elif s[1] == '-':
            l.append(float(s[0]) - float(s[2]))
            lab['text'] = l[-1]

        elif s[1] == '/':
            l.append(float(s[0]) / float(s[2]))
            lab['text'] = l[0]

        elif s[1] == '*':
            l.append(float(s[0]) * float(s[2]))
            lab['text'] = l[-1]
    except:
        lab['text'] = 'WRONG SINTAX, TRY TO USE SPACES BETWEEN ARGUMENTS'
    ent.delete(0, 100)
    pos = 0
    ans = l
    
def symbh(event):
    global pos
    ent.insert(pos, ans)    
    pos += len(str(ans))

def symb1(event):
    global pos
    ent.insert(pos, '1')
    pos += 1

def symb2(event):
    global pos
    ent.insert(pos, '2')
    pos += 1
    
def symb3(event):
    global pos
    ent.insert(pos, '3')
    pos += 1
    
def symb4(event):
    global pos
    ent.insert(pos, '4')
    pos += 1
    
def symb5(event):
    global pos
    ent.insert(pos, '5')
    pos += 1
    
def symb6(event):
    global pos
    ent.insert(pos, '6')
    pos += 1
    
def symb7(event):
    global pos
    ent.insert(pos, '7')
    pos += 1
    
def symb8(event):
    global pos
    ent.insert(pos, '8')
    pos += 1
    
def symb9(event):
    global pos
    ent.insert(pos, '9')
    pos += 1
    
def symb0(event):
    global pos
    ent.insert(pos, '0')
    pos += 1

def symbp(event):
    global pos
    ent.insert(pos, ' + ')
    pos += 3
    
def symbm(event):
    global pos
    ent.insert(pos, ' - ')
    pos += 3
    
def symbd(event):
    global pos
    ent.insert(pos, ' / ')
    pos += 3
    
def symbmul(event):
    global pos
    ent.insert(pos, ' * ')
    pos += 3
    

pos = 0    
root  = Tk()
f_top = Frame(root)
f_mid = Frame(root)
f_bot = Frame(root)
f_botbot = Frame(root)
ent = Entry(root, width=30)
buth = Button(f_botbot, text="h")
butmul = Button(f_mid, text="*")
butdiv = Button(f_bot, text="/")
buteq = Button(f_top, text="=")
but1 = Button(f_bot, text="1")
but2 = Button(f_bot, text="2")
but3 = Button(f_bot, text="3")
but4 = Button(f_mid, text="4")
but5 = Button(f_mid, text="5")
but6 = Button(f_mid, text="6")
but7 = Button(f_top, text="7")
but8 = Button(f_top, text="8")
but9 = Button(f_top, text="9")
but0 = Button(f_botbot, text="0")
butm = Button(f_botbot, text="-")
butp = Button(f_botbot, text="+")
lab = Label(root, width=30, 
            bg='black', fg='white')

    
buteq.bind('<Button-1>', oper)
but1.bind('<Button-1>', symb1)
but2.bind('<Button-1>', symb2)
but3.bind('<Button-1>', symb3)
but4.bind('<Button-1>', symb4)
but5.bind('<Button-1>', symb5)
but6.bind('<Button-1>', symb6)
but7.bind('<Button-1>', symb7)
but8.bind('<Button-1>', symb8)
but9.bind('<Button-1>', symb9)
but0.bind('<Button-1>', symb0)
butm.bind('<Button-1>', symbm)
butp.bind('<Button-1>', symbp)
butdiv.bind('<Button-1>', symbd)
butmul.bind('<Button-1>', symbmul)
buth.bind('<Button-1>', symbh)


ent.pack()
f_top.pack()
f_mid.pack()
f_bot.pack()
f_botbot.pack()
but7.pack(side=LEFT)
but8.pack(side=LEFT)
but9.pack(side=LEFT)
buteq.pack(side=LEFT)
but6.pack(side=LEFT)
but5.pack(side=LEFT)
but4.pack(side=LEFT)
butmul.pack(side=LEFT)
but1.pack(side=LEFT)
but2.pack(side=LEFT)
but3.pack(side=LEFT)
butdiv.pack(side=LEFT)
butp.pack(side=LEFT)
but0.pack(side=LEFT)
butm.pack(side=LEFT)
buth.pack(side=LEFT)

lab.pack()
root.mainloop()

# %% [markdown]
# #####
